# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishita-01/Cognitive-Lab/blob/main/CC_Assi6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ques 1

# %%
import numpy as np
import matplotlib.pyplot as plt

M = int(input())
x = np.linspace(-10, 10)

y1 = M * x**2
y2 = M * np.sin(x)

plt.figure(figsize=(8, 5))
plt.plot(x, y1, label='y = M * x^2', color='blue', linestyle='-', linewidth=2)
plt.plot(x, y2, label='y = M * sin(x)', color='red', linestyle='--', linewidth=2)

# Add labels, legend, and grid
plt.xlabel("x values")
plt.ylabel("y values")
plt.title(f"Plot of $M \cdot x^2$ and $M \cdot \sin(x)$ (M = {M})")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
# Out:
# 5

# %% [markdown]
# Ques 2

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    "Subject": ["Math", "Science", "English", "History", "Computer"],
    "Score": [85, 78, 92, 74, 88]
}


df = pd.DataFrame(data)
sns.set_style("whitegrid")

plt.figure(figsize=(8, 5))
colors = ["blue", "red", "green", "purple", "orange"]
barplot = sns.barplot(x="Subject", y="Score", data=df, palette=colors)

for index, row in df.iterrows():
    plt.text(index, row.Score + 1, str(row.Score), ha="center", fontsize=12, fontweight='bold')


plt.title("Student's Scores in Different Subjects", fontsize=14, fontweight='bold')
plt.xlabel("Subjects", fontsize=12)
plt.ylabel("Scores", fontsize=12)
plt.grid(axis='y', linestyle="--", alpha=0.7)


plt.show()
# Out:
# <ipython-input-3-5528c3d2700a>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x="Subject", y="Score", data=df, palette=colors)

# %% [markdown]
# Ques 3

# %%
rno = int(input())
np.random.seed(rno)
dataset = np.random.randn(50)
fig, axes = plt.subplots(2,2,figsize = (10,8))

axes[0, 0].plot(np.cumsum(dataset),marker ="o", linestyle="-")
axes[0, 0].set_title('Cumulative Sum')
axes[0, 0].set_xlabel('Data Point')
axes[0, 0].set_ylabel('Cumulative Sum')
axes[0, 0].grid(True)

noise = np.random.randn(50) * 0.2
axes[1, 1].scatter(dataset, dataset + noise, marker='x', color='red')
axes[1, 1].set_title('Scatter Plot with Random Noise')
axes[1, 1].set_xlabel('X-axis')
axes[1, 1].set_ylabel('Y-axis')
axes[1, 1].grid(True)



plt.show()
# Out:
# 102317254

# %% [markdown]
# Ques 4

# %%
df = pd.read_csv("/content/company_sales_data.csv")
df.head()

fig, axes = plt.subplots(2,2,figsize = (10,8))
sns.lineplot(x="month_number", y ="total_profit",data=df, palette="viridis",ax = axes[0,0])
axes[0,0].set_title("Total_profit for all months")
axes[0,0].set_xlabel("Month number")
axes[0,0].set_ylabel("Total_profit")
axes[0,0].grid(True)

# Select the columns for product sales data
products = ['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo', 'moisturizer']
for product in products:
    sns.lineplot(x='month_number', y=product, data=df, label=product, ax = axes[0,1])
plt.legend()
plt.show()
axes[0,1].set_title("Product Sales Data")
axes[0,1].set_xlabel("Month number")
axes[0,1].set_ylabel("Sales")
axes[0,1].grid(True)

plt.show()


#3. Bar chart for all features
plt.figure(figsize=(16, 5))
df.drop(columns='month_number').sum().plot(kind='bar')
plt.title('Bar Chart for All Features/Attributes')
plt.xlabel('Features')
plt.ylabel('Value')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.tight_layout() # Adjust layout to prevent overlapping labels
plt.show()
# Out:
# <ipython-input-6-006b500ae9e8>:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x="month_number", y ="total_profit",data=df, palette="viridis",ax = axes[0,0])
# <ipython-input-6-006b500ae9e8>:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
