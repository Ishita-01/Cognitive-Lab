# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishita-01/Cognitive-Lab/blob/main/CC_Ass7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

roll_number = 102317254
np.random.seed(roll_number)



# Creating DataFrame
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
categories = ['Electronics', 'Clothing', 'Home & Kitchen', 'Sports']
sales_data = np.random.randint(1000, 5001, (12, 4))
sales_df = pd.DataFrame(sales_data, columns=categories, index=months)

print(sales_df.head())
print(sales_df.describe())
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         1002      4050            2814    4680
# Feb         1496      2629            1866    4636
# Mar         2717      1370            1419    3258
# Apr         1931      2902            2270    2793
# May         2253      2943            4347    1515
#        Electronics     Clothing  Home & Kitchen       Sports
# count    12.000000    12.000000       12.000000    12.000000
# mean   2607.666667  2785.333333     3304.833333  3396.666667
# std    1190.613084  1005.159719     1279.778165  1234.317871
# min    1002.000000  1370.000000     1419.000000  1077.000000
# 25%    1864.500000  1984.750000     2169.000000  2841.750000
# 50%    2294.000000  2921.000000     3700.500000  3459.500000
# 75%    3096.000000  3559.000000     4377.500000  4393.000000
# max    4980.000000  4115.000000     4711.000000  4912.000000

# %%
total_sales_category = sales_df.sum()
print("Total sales per category:\n", total_sales_category)

sales_df['Total Sales'] = sales_df.sum(axis=1)
print("Total sales per month:\n", sales_df['Total Sales'])
# Out:
# Total sales per category:
#  Electronics       31292
# Clothing          33424
# Home & Kitchen    39658
# Sports            40760
# dtype: int64
# Total sales per month:
#  Jan    12546
# Feb    10627
# Mar     8764
# Apr     9896
# May    11058
# Jun    11221
# Jul    13836
# Aug    15794
# Sep    11547
# Oct    15938
# Nov    12517
# Dec    11390
# Name: Total Sales, dtype: int64

# %%
average_growth = sales_df.pct_change().mean()

print("\nAverage sales growth between consecutive months:")
print(average_growth)

sales_df['Growth Rate'] = sales_df['Total Sales'].pct_change() * 100
# Out:
# Average sales growth between consecutive months:
# Electronics       0.169796
# Clothing          0.181221
# Home & Kitchen    0.195221
# Sports            0.250920
# Total Sales       0.010392
# dtype: float64

# %%
print("Percentage change in Total Sales from the previous month.:\n", sales_df['Growth Rate'])
# Out:
# Percentage change in Total Sales from the previous month.:
#  Jan          NaN
# Feb   -15.295712
# Mar   -17.530818
# Apr    12.916476
# May    11.742118
# Jun     1.474046
# Jul    23.304518
# Aug    14.151489
# Sep   -26.889958
# Oct    38.027193
# Nov   -21.464425
# Dec    -9.003755
# Name: Growth Rate, dtype: float64

# %%
if roll_number % 2 == 0:
    sales_df['Electronics'] *= 0.9  # 10% discount
else:
    sales_df['Clothing'] *= 0.85  # 15% discount

print("\nSales data after discount:")
print(sales_df)
# Out:
# Sales data after discount:
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan        901.8      4050            2814    4680        12546          NaN
# Feb       1346.4      2629            1866    4636        10627   -15.295712
# Mar       2445.3      1370            1419    3258         8764   -17.530818
# Apr       1737.9      2902            2270    2793         9896    12.916476
# May       2027.7      2943            4347    1515        11058    11.742118
# Jun       1911.6      1466            4711    2920        11221     1.474046
# Jul       2774.7      3426            4469    2858        13836    23.304518
# Aug       4113.9      2940            3971    4312        15794    14.151489
# Sep       2101.5      4115            1436    3661        11547   -26.889958
# Oct       4482.0      1468            4578    4912        15938    38.027193
# Nov       2821.5      3958            4347    1077        12517   -21.464425
# Dec       1498.5      2157            3430    4138        11390    -9.003755

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 5))
sales_df[categories].plot(marker='o')
plt.title("Monthly Sales Trends")
plt.xlabel("Month")
plt.ylabel("Sales Units")
plt.legend()
plt.grid()
plt.show()

# Boxplot for sales distribution
plt.figure(figsize=(8, 5))
sns.boxplot(data=sales_df[categories])
plt.title("Sales Distribution by Category")
plt.show()

# %%
array = np.array([[1, -2, 3],[-4, 5, -6]])
print("Element-wise absolute:", np.abs(array))

arr = array.flatten()
print("Percentiles:", np.percentile(arr, [25, 50, 75]))
print("Mean:", np.mean(arr))
print("Median:", np.median(arr))
print("Standard Deviation:", np.std(arr))
# Out:
# Element-wise absolute: [[1 2 3]
#  [4 5 6]]
# Percentiles: [-3.5 -0.5  2.5]
# Mean: -0.5
# Median: -0.5
# Standard Deviation: 3.8622100754188224

# %%
arr = np.array([-1.8, -1.6, -0.5, 0.5,1.6, 1.8, 3.0])
print("Floor:", np.floor(arr))
print("Ceiling:", np.ceil(arr))
print("Truncated:", np.trunc(arr))
print("Rounded:", np.round(arr))
# Out:
# Floor: [-2. -2. -1.  0.  1.  1.  3.]
# Ceiling: [-1. -1. -0.  1.  2.  2.  3.]
# Truncated: [-1. -1. -0.  0.  1.  1.  3.]
# Rounded: [-2. -2. -0.  0.  2.  2.  3.]

# %%
def swap_list_elements(lst, idx1, idx2):
    temp = lst[idx1]
    lst[idx1] = lst[idx2]
    lst[idx2] = temp
    return lst

example_list = [1, 2, 3, 4, 5]
print("Before Swap:", example_list)
print("After Swap:", swap_list_elements(example_list, 1, 3))
# Out:
# Before Swap: [1, 2, 3, 4, 5]
# After Swap: [1, 4, 3, 2, 5]

# %%
ex_set = {1, 2, 3, 4, 5}
ex_list = list(ex_set)
ex_list[0], ex_list[1] = ex_list[1], ex_list[0]
ex_set = set(ex_list)
print("Swapped Set:", ex_set)
# Out:
# Swapped Set: {1, 2, 3, 4, 5}
